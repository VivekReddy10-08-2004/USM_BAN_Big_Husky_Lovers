# %% [markdown]
# <a href="https://colab.research.google.com/github/VivekReddy10-08-2004/USM_BAN_Big_Husky_Lovers/blob/main/Notebooks/BAN_Hackathon_basic_data_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/VivekReddy10-08-2004/USM_BAN_Big_Husky_Lovers/refs/heads/main/Open%20Reqs%20Mar%202026_2026-04-01.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   JOB_REQUISITION                   216 non-null    object
#  1   WORKER_SUB_TYPE                   216 non-null    object
#  2   DAYS_OPEN                         216 non-null    object
#  3   PRIMARY_LOCATION                  216 non-null    object
#  4   JOB_PROFILE                       216 non-null    object
#  5   MANAGEMENT_LEVEL_JOB_REQUISITION  211 non-null    object
#  6   NUMBER_OF_OPENINGS_AVAILABLE      216 non-null    int64
#  7   JOB_DESCRIPTION                   216 non-null    object
#  8   JOB_PROFILE_SUMMARY               216 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 15.3+ KB

# %%
df.shape
# Out:
# (216, 9)

# %%
df.head()
# Out:
#                                      JOB_REQUISITION WORKER_SUB_TYPE  \
# 0  Director, Security Operations & Resilience (Open)         Regular
# 1                          Employment Counsel (Open)         Regular
# 2  R&D PCR Assay Development Scientist (Evergreen...         Regular
# 3              Transportation Network Planner (Open)         Regular
# 4  Field Sales Veterinary Diagnostics Santa Cruz ...         Regular
#
#       DAYS_OPEN PRIMARY_LOCATION                           JOB_PROFILE  \
# 0  236 days ago               US                           Director IT
# 1   85 days ago               US                     Corporate Counsel
# 2   39 days ago               US                          Scientist II
# 3   20 days ago               GB  Labs Transportation Associate Sr III
# 4  141 days ago               US   Veterinary Diagnostic Consultant II
#
#   MANAGEMENT_LEVEL_JOB_REQUISITION  NUMBER_OF_OPENINGS_AVAILABLE  \
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1-L6-lsX1c8sOaFIR6cG5JBFWfudLE3THPG8Iv5G9IPY/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1-L6-lsX1c8sOaFIR6cG5JBFWfudLE3THPG8Iv5G9IPY/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df.isna()
# Out:
#      JOB_REQUISITION  WORKER_SUB_TYPE  DAYS_OPEN  PRIMARY_LOCATION  \
# 0              False            False      False             False
# 1              False            False      False             False
# 2              False            False      False             False
# 3              False            False      False             False
# 4              False            False      False             False
# ..               ...              ...        ...               ...
# 211            False            False      False             False
# 212            False            False      False             False
# 213            False            False      False             False
# 214            False            False      False             False
# 215            False            False      False             False
#
#      JOB_PROFILE  MANAGEMENT_LEVEL_JOB_REQUISITION  \
# 0          False                             False
# 1          False                             False
# ...
